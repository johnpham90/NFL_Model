# %%
import os
import sys
notebook_dir = os.path.abspath(os.path.dirname(''))
project_root = os.path.dirname(notebook_dir)
sys.path.append(project_root)
import pandas as pd
import psycopg2
from src.utils.db_utils import get_connection, execute_query

season = '2024'
def create_defense_team_id(df):
    team_id=[]

    for i_game in df.index:
        if df.loc[i_game, 'teamid']==df.loc[i_game, 'awayteamid']:
            team_id.append(df.loc[i_game, 'hometeamid'])
        else:
            team_id.append(df.loc[i_game, 'awayteamid'])
    df['defenseid']=team_id

    return df

def fetch_and_get_opponents(season, stat):
    """
    Fetch team stats and determine the opponent for each row based on the query results.

    Args:
        season (int): The season year to filter the data.
        stat (str): The statistic to include in the query.

    Returns:
        pd.DataFrame: DataFrame with team stats and opponent team information.
    """
    # Define your query
    query = f"""
    SELECT *
    FROM stats.teamstats 
    WHERE season = {season}
    """
    
    # Execute the query (replace with your actual database function)
    query_results = execute_query(query)  # Replace with actual DB execution function
    query_results_process = create_defense_team_id(query_results)

    return query_results_process

# %%
season = '2024'
stat = 'total_yards'

# Call the function and store the DataFrame
results = fetch_and_get_opponents(season, stat)

# Print the entire DataFrame
print(results)

# If you want to print specific columns
print(results[['teamid', 'defenseid', stat]])
# Out:
# Successfully connected to the database!
#                               teamstatsid    gamesummaryid teamid awayteamid  \
# 0    df6bae3b-0387-439a-a965-b854f923eebb  gs-202401BALKAN    BAL        BAL
# 1    4dd877ea-00da-49d1-bcc4-96ddc82e4d06  gs-202401BALKAN    KAN        BAL
# 2    3cee4249-eb58-441e-9de4-fd49b57e6beb  gs-202401GNBPHI    GNB        GNB
# 3    7eea7b0e-6258-4a04-980b-6eb68b5f6a7a  gs-202401GNBPHI    PHI        GNB
# 4    0dc27ef8-6e23-41f8-ac47-7349b1fe87a9  gs-202401PITATL    PIT        PIT
# ..                                    ...              ...    ...        ...
# 443  d0903394-f384-4830-88c5-c399de623cdf  gs-202415GNBSEA    SEA        GNB
# 444  ce576230-3b32-463b-9c28-87698925933e  gs-202415CHIMIN    CHI        CHI
# 445  377c1a3e-088d-446e-86b4-90901be728e1  gs-202415CHIMIN    MIN        CHI
# 446  606c1c4f-72d3-457d-a05c-5930e930db36  gs-202415ATLLVR    ATL        ATL
# 447  74b69d97-5c32-40f9-8dcc-b80124c0c251  gs-202415ATLLVR    LVR        ATL
#
#     hometeamid  team time_of_possession  week  net_pass_yards  \
# 0          KAN  None              33:43     1             267
# 1          KAN  None              26:17     1             281
# 2          PHI  None              27:13     1             251
# 3          PHI  None              32:47     1             266
# 4          ATL  None              35:36     1             133
# ..         ...   ...                ...   ...             ...
# 443        SEA  None              27:02    15             128
# 444        MIN  None              30:06    15             171
# 445        MIN  None              29:54    15             215
# 446        LVR  None              33:52    15              93
# 447        LVR  None              26:08    15             184
#
#                 hometeam  ...  fumbles_lost turnovers          date  \
# 0     Kansas City Chiefs  ...           1-1         1   Sep 5, 2024
# 1     Kansas City Chiefs  ...           0-0         1   Sep 5, 2024
# 2    Philadelphia Eagles  ...           1-0         1   Sep 6, 2024
# 3    Philadelphia Eagles  ...           2-1         3   Sep 6, 2024
# 4        Atlanta Falcons  ...           1-0         0   Sep 8, 2024
# ..                   ...  ...           ...       ...           ...
# 443     Seattle Seahawks  ...           0-0         2  Dec 15, 2024
# 444    Minnesota Vikings  ...           1-1         1  Dec 16, 2024
# 445    Minnesota Vikings  ...           0-0         1  Dec 16, 2024
# 446    Las Vegas Raiders  ...           1-0         1  Dec 16, 2024
# 447    Las Vegas Raiders  ...           1-1         3  Dec 16, 2024
#
#     sacked_yards third_down_conv  total_yards first_downs penalties_yards  \
# 0            1-6            7-14          452          25            7-64
# 1           2-10             4-9          353          21            6-45
# 2            2-9            3-11          414          19           10-71
# 3           2-12            4-14          410          25            7-57
# 4           2-23            8-17          270          16            9-60
# ..           ...             ...          ...         ...             ...
# 443         7-45            4-13          208          14           5-108
# 444         2-25            1-12          284          16            9-93
# 445         2-16            7-14          329          24           10-56
# 446         3-19            4-13          261          14            6-30
# 447         4-24            4-14          249          16            7-55
#
#                 awayteam  defenseid
# 0       Baltimore Ravens        KAN
# 1       Baltimore Ravens        BAL
# 2      Green Bay Packers        PHI
# 3      Green Bay Packers        GNB
# 4    Pittsburgh Steelers        ATL
# ..                   ...        ...
# 443    Green Bay Packers        GNB
# 444        Chicago Bears        MIN
# 445        Chicago Bears        CHI
# 446      Atlanta Falcons        LVR
# 447      Atlanta Falcons        ATL
#
# [448 rows x 24 columns]
#     teamid defenseid  total_yards
# 0      BAL       KAN          452
# 1      KAN       BAL          353
# 2      GNB       PHI          414
# 3      PHI       GNB          410
# 4      PIT       ATL          270
# ..     ...       ...          ...
# 443    SEA       GNB          208
# 444    CHI       MIN          284
# 445    MIN       CHI          329
# 446    ATL       LVR          261
# 447    LVR       ATL          249
#
# [448 rows x 3 columns]
