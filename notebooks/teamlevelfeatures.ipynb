# %%
import os
import sys
import numpy as np
notebook_dir = os.path.abspath(os.path.dirname(''))
project_root = os.path.dirname(notebook_dir)
sys.path.append(project_root)
import pandas as pd
from src.utils.db_utils import get_connection, execute_query
from src.features import team_level_features_class

# %%
team_feautres=team_level_features_class.TeamLevelFeatures()
# Out:
# Successfully connected to the database!

# %%
team_feautres.team_stats_dict[list(team_feautres.team_stats_dict.keys())[5]]
# Out:
#                 ARI         ATL         BAL         BUF         CAR  \
# 2004_1          NaN         NaN         NaN         NaN         NaN
# 2004_2   260.000000  227.000000  254.000000  242.000000  300.000000
# 2004_3   213.500000  321.500000  256.500000  242.500000  329.000000
# 2004_4   222.333333  308.666667  297.666667  242.500000  329.000000
# 2004_5   260.000000  309.750000  275.000000  274.000000  339.333333
# ...             ...         ...         ...         ...         ...
# 2024_11  346.400000  375.100000  440.200000  343.200000  280.700000
# 2024_12  346.400000  361.545455  430.090909  345.272727  280.700000
# 2024_13  342.000000  361.545455  426.666667  345.272727  285.545455
# 2024_14  347.333333  360.583333  422.461538  347.500000  292.333333
# 2024_15  348.000000  371.000000  422.461538  355.000000  293.076923
#
#                 CHI         CIN         CLE         DAL         DEN  ...  \
# 2004_1          NaN         NaN         NaN         NaN         NaN  ...
# ...

# %%
list(team_feautres.team_stats_dict.keys())[0]
# Out:
# 'deffensive net_pass_yards'
