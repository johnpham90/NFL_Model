# %%
import requests
import datetime as dt
from typing import List, Dict
from src.utils.current_week_utils import get_current_nfl_week

nfl_week_data = get_current_nfl_week()

# Display the current week
if nfl_week_data['current_week']:
    print(f"Current Week: {nfl_week_data['current_week']}")
    print("\nGames this week:")
    
    # Display each game
    for game in nfl_week_data['games']:
        game_date = game['date']
        away_team = game['away_team']
        home_team = game['home_team']
        print(f"{away_team} @ {home_team} on {game_date}")
else:
    print("Unable to determine the current NFL week or fetch game data.")
