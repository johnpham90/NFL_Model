# %% [markdown]
# # Test Supabase Database Connection
#
# This notebook tests the connection to our Supabase database and performs some basic queries using our db_utils module.

# %%
import pandas as pd
from src.utils.db_utils import get_connection, execute_query

# Test connection
engine = get_connection()

# %% [markdown]
# ## Test Query
# Let's try a simple query to list all tables in our database

# %%
# Query to get all tables
query = """
SELECT table_name 
FROM information_schema.tables 
WHERE table_schema = 'public';
"""

tables_df = execute_query(query)
print('\nTables in database:')
display(tables_df)
