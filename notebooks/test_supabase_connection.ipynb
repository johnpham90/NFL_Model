# %% [markdown]
# # Test Supabase Database Connection
#
# This notebook demonstrates how to connect to our Supabase database using the db_utils module.
#
# ## How to Use This Notebook
# 1. Make sure your .env file contains the correct DATABASE_URL
# 2. Run each cell by clicking the play button (▶️) or pressing Shift+Enter
# 3. Check the output of each cell to verify it worked
#
# Note: Cells must be run in order as later cells depend on the connections established in earlier cells.
#
# To use db_utilis script, add the utilitly to each notebook

# %%
# db_utils scrip
# Add to each notebook

import os
import sys
notebook_dir = os.path.abspath(os.path.dirname(''))
project_root = os.path.dirname(notebook_dir)
sys.path.append(project_root)
import pandas as pd
from src.utils.db_utils import get_connection, execute_query

print(f'Project root added to path: {project_root}')
# Out:
# Project root added to path: c:\NFL Predictive Model\Model\NFL_Model

# %%
# Test the database connection
print('Testing database connection...')
engine = get_connection()

if engine:
    print('✅ Connection successful!')
else:
    print('❌ Connection failed. Check your .env file and database credentials.')
# Out:
# Testing database connection...
# Successfully connected to the database!
# ✅ Connection successful!

# %% [markdown]
# ## Step 2: View Available Tables
# Run this cell to see what tables are available in the database:

# %%
# Query to list all tables in the public schema
query = """
SELECT table_name, table_type
FROM information_schema.tables 
WHERE table_schema = 'stats'
ORDER BY table_name;
"""

tables_df = execute_query(query)
print('Tables in database:')
display(tables_df)
# Out:
# Successfully connected to the database!
# Tables in database:
#                table_name  table_type
# 0                 defense  BASE TABLE
# 1        defense_advanced  BASE TABLE
# 2            drivedetails  BASE TABLE
# 3              drivestats  BASE TABLE
# 4             gamesummary  BASE TABLE
# 5                 kicking  BASE TABLE
# 6            nfl_stadiums  BASE TABLE
# 7                nflteams  BASE TABLE
# 8                 offense  BASE TABLE
# 9                 passing  BASE TABLE
# 10              receiving  BASE TABLE
# 11                returns  BASE TABLE
# 12                rushing  BASE TABLE
# 13              teamstats  BASE TABLE
# 14           view_defense        VIEW
# 15  view_defense_advanced        VIEW
# 16      view_drivedetails        VIEW
# 17        view_drivestats        VIEW
# 18       view_gamesummary        VIEW
# 19           view_kicking        VIEW
# 20           view_offense        VIEW
# 21           view_passing        VIEW
# 22         view_receiving        VIEW
# 23           view_returns        VIEW
# 24           view_rushing        VIEW
# 25         view_teamstats        VIEW

# %% [markdown]
# ## Step 3: Test a Custom Query
# Now you can write your own query. Here's an example - modify it for your needs:

# %%
# Example: Query with parameters
# Replace table_name and column_name with actual names from your database
query = """
SELECT *
FROM stats.gamesummary
WHERE season = '2024'
LIMIT 5;
"""

tables_df = execute_query(query)
print('Games in Database')
display(tables_df)
# Out:
# Successfully connected to the database!
# Games in Database
#      gamesummaryid awayteamid hometeamid  awayscore game_time  week  \
# 0  gs-202401BALKAN        BAL        KAN         20    8:20pm     1
# 1  gs-202401GNBPHI        GNB        PHI         29    8:15pm     1
# 2  gs-202401PITATL        PIT        ATL         18    1:00pm     1
# 3  gs-202401ARIBUF        ARI        BUF         28    1:00pm     1
# 4  gs-202401TENCHI        TEN        CHI         17    1:00pm     1
#
#             won_toss             hometeam  over_under  season    surface  \
# 0  Chiefs (deferred)   Kansas City Chiefs        47.0    2024      grass
# 1            Packers  Philadelphia Eagles        49.5    2024       None
# 2            Falcons      Atlanta Falcons        42.0    2024  fieldturf
# 3          Cardinals        Buffalo Bills        46.5    2024     a_turf
# 4   Bears (deferred)        Chicago Bears        44.5    2024      grass
#
#    homescore attendance                vegas_line         date  \
# 0         27     73,611   Kansas City Chiefs -3.0  Sep 5, 2024
# 1         34     47,236  Philadelphia Eagles -2.0  Sep 6, 2024
# 2         10     72,291      Atlanta Falcons -3.5  Sep 8, 2024
# 3         34     70,542        Buffalo Bills -6.5  Sep 8, 2024
# 4         24     59,403        Chicago Bears -3.5  Sep 8, 2024
#
#                         roof duration             awayteam
# 0                   outdoors     3:10     Baltimore Ravens
# 1                       None     3:29    Green Bay Packers
# 2  retractable roof (closed)     2:56  Pittsburgh Steelers
# 3                   outdoors     2:59    Arizona Cardinals
# 4                   outdoors     3:00     Tennessee Titans
