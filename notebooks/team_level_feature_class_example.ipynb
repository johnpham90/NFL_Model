# %%
import pandas as pd
import numpy as np
import os
import sys
notebook_dir = os.path.abspath(os.path.dirname(''))
project_root = os.path.dirname(notebook_dir)
sys.path.append(project_root)
import pandas as pd
from src.utils.db_utils import get_connection, execute_query
from src.features import team_level_features_class

# %%
data=team_level_features_class.TeamLevelFeatures()
# Out:
# Successfully connected to the database!

# %%
# data.team_stats_dict['offensive total_yards']

# %%
data.data[['teamid', 'hometeamid','awayteamid','defenseid']]
# Out:
#      teamid hometeamid awayteamid defenseid
# 3091    CAR        DEN        CAR       DEN
# 3092    DEN        DEN        CAR       CAR
# 3093    GNB        JAX        GNB       JAX
# 3094    JAX        JAX        GNB       GNB
# 3095    BUF        BAL        BUF       BAL
# ...     ...        ...        ...       ...
# 4822    SEA        SEA        GNB       GNB
# 4823    CHI        MIN        CHI       MIN
# 4824    MIN        MIN        CHI       CHI
# 4825    ATL        LVR        ATL       LVR
# 4826    LVR        LVR        ATL       ATL
#
# [4828 rows x 4 columns]

# %%
np.where(data.data['teamid']==data.data['defenseid'])[0]
# Out:
# array([], dtype=int64)
